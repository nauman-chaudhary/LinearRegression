# %%
import numpy as np
import matplotlib.pyplot as plt
#import graphlab

# %%
x = np.array(range(-100,100,5))

# %%
y1 = x**2
plt.plot(x, y1)

# %%
y2 = x**3
plt.plot(x, y2)

# %%
y3 = x**4
plt.plot(x, y3)

# %%
y = y1 + 100000 * y2 + y3
plt.plot(x, y)

# %%
y1 = 14 * np.sin(0.05*x)
y2 = 5 * np.sin(5*x)
y3 = 10 * np.sin(100*x)

y = y1 + 5 * y2 + 2 * y3

plt.plot(x,y)

# %%
data = np.arange(-10, 11).reshape(-1,1)
target = 10 + 2*data + 5*data**2
plt.plot(data, target)

# %%
degree = 2
data = np.hstack((data,np.power(data,np.arange(start=2,stop=degree+1))))

# %%
np.divide(np.subtract(data[:,0],np.mean(data[:,0])), np.std(data[:,0])).reshape(-1,1)
# Out:
# array([[-1.65144565],
#        [-1.48630108],
#        [-1.32115652],
#        [-1.15601195],
#        [-0.99086739],
#        [-0.82572282],
#        [-0.66057826],
#        [-0.49543369],
#        [-0.33028913],
#        [-0.16514456],
#        [ 0.        ],
#        [ 0.16514456],
#        [ 0.33028913],
#        [ 0.49543369],
#        [ 0.66057826],
#        [ 0.82572282],
#        [ 0.99086739],
#        [ 1.15601195],
#        [ 1.32115652],
#        [ 1.48630108],
#        [ 1.65144565]])

# %%
np.divide(np.subtract(data[:,0],np.mean(data[:,0])), np.std(data[:,0])).reshape(-1,1)
# Out:
# array([[-1.65144565],
#        [-1.48630108],
#        [-1.32115652],
#        [-1.15601195],
#        [-0.99086739],
#        [-0.82572282],
#        [-0.66057826],
#        [-0.49543369],
#        [-0.33028913],
#        [-0.16514456],
#        [ 0.        ],
#        [ 0.16514456],
#        [ 0.33028913],
#        [ 0.49543369],
#        [ 0.66057826],
#        [ 0.82572282],
#        [ 0.99086739],
#        [ 1.15601195],
#        [ 1.32115652],
#        [ 1.48630108],
#        [ 1.65144565]])

# %%
data = np.arange(-10, 11).reshape(-1,1)
data = data.astype(float)
target = 10 + 2*data + 5*data**2
# plt.plot(data, target)
degree = 2
data = np.hstack((data,np.power(data,np.arange(start=2,stop=degree+1))))
for i in range(data.shape[1]):
    data[:,i] = np.divide(np.subtract(data[:,i],np.mean(data[:,i])), np.std(data[:,i])).astype(float)
print(type(data[0,0]))
data
# Out:
# <class 'numpy.float64'>
# array([[-1.65144565,  1.93776694],
#        [-1.48630108,  1.35643686],
#        [-1.32115652,  0.83629942],
#        [-1.15601195,  0.37735461],
#        [-0.99086739, -0.02039755],
#        [-0.82572282, -0.35695707],
#        [-0.66057826, -0.63232395],
#        [-0.49543369, -0.84649819],
#        [-0.33028913, -0.99947979],
#        [-0.16514456, -1.09126875],
#        [ 0.        , -1.12186507],
#        [ 0.16514456, -1.09126875],
#        [ 0.33028913, -0.99947979],
#        [ 0.49543369, -0.84649819],
#        [ 0.66057826, -0.63232395],
#        [ 0.82572282, -0.35695707],
#        [ 0.99086739, -0.02039755],
#        [ 1.15601195,  0.37735461],
#        [ 1.32115652,  0.83629942],
#        [ 1.48630108,  1.35643686],
#        [ 1.65144565,  1.93776694]])

# %%
data[:,0].reshape(-1,1)
# Out:
# (21, 1)
